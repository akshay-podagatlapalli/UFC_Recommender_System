# %%
import math 
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ufc_df = pd.read_excel("../data_i/raw/i_ufc_grouped_data_target.xlsx")

# %%
ufc_df.columns
# Out:
# Index(['Fighter', 'KD', 'SUB_ATT', 'SIG_STR_pct', 'REV', 'SIG_STR._lan',
#        'SIG_STR._att', 'TOTAL_STR._lan', 'TOTAL_STR._att', 'TD_lan', 'TD_att',
#        'HEAD_lan', 'HEAD_att', 'BODY_lan', 'BODY_att', 'LEG_lan', 'LEG_att',
#        'DISTANCE_lan', 'DISTANCE_att', 'CLINCH_lan', 'CLINCH_att',
#        'GROUND_lan', 'GROUND_att', 'pct_SIG_STR', 'pct_TOTAL_STR', 'pct_TD',
#        'pct_HEAD', 'pct_BODY', 'pct_LEG', 'pct_DISTANCE', 'pct_CLINCH',
#        'pct_GROUND', 'DIST_pct', 'CTRL_RT', 'SLpM', 'Str_Acc', 'SApM',
#        'Str_Def', 'TD_Avg', 'TD_Acc', 'TD_Def', 'Sub_Avg', 'CTRL', 'CTRLLD',
#        'fight_time', 'avg_fight_time', 'DIST', 'Total_Fights', 'Win', 'Loss',
#        'Draw', 'longest_win_streak', 'win_by_Decision_Majority',
#        'win_by_Decision_Split', 'win_by_Decision_Unanimous', 'win_by_KO/TKO',
#        'win_by_Submission', 'win_by_TKO_Doctor_Stoppage', 'Height_cms',
#        'Reach_cms', 'Weight_lbs', 'R_age', 'division', 'label', 'lab_num'],
#       dtype='object')

# %%
ufc_df.head(10)
# Out:
#                 Fighter  KD  SUB_ATT  SIG_STR_pct  REV  SIG_STR._lan  \
# 0            Aalon Cruz   0        0         0.16    0             2
# 1           Aaron Brink   0        0         0.00    0             0
# 2        Aaron Phillips   0        1         1.55    1            62
# 3           Aaron Riley   0        1         3.10    0           314
# 4            Aaron Rosa   0        0         0.99    0           132
# 5         Aaron Simpson   6        4         6.13    0           454
# 6       Aaron Wilkinson   0        0         0.00    1             0
# 7  Abdul Razak Alhassan   6        0         4.01    1           179
# 8    Abdul-Kerim Edilov   0        1         0.61    0            77
# 9         Abel Trujillo   3        3         4.03    0           273
#
#    SIG_STR._att  TOTAL_STR._lan  TOTAL_STR._att  TD_lan  ...  win_by_KO/TKO  \
# 0            15               2              15       0  ...              0
# 1             5               0               5       0  ...              0
# 2           109             346             432       0  ...              0
# 3           904             581            1190       8  ...              0
# 4           290             407             598       0  ...              0
# 5           860             800            1265      32  ...              2
# 6             1               0               1       1  ...              0
# 7           371             197             395       2  ...              4
# 8           125             150             210       2  ...              0
# 9           662             370             767      15  ...              3
#
#    win_by_Submission  win_by_TKO_Doctor_Stoppage  Height_cms  Reach_cms  \
# 0                  0                           0      182.88     198.12
# 1                  0                           0      190.50        NaN
# 2                  0                           0      175.26     180.34
# 3                  0                           0      172.72     175.26
# 4                  0                           0      193.04     195.58
# 5                  0                           0      182.88     185.42
# 6                  0                           0      177.80        NaN
# 7                  0                           0      177.80     185.42
# 8                  0                           0      187.96        NaN
# 9                  1                           0      172.72     177.80
#
#    Weight_lbs  R_age                    division  \
# 0       145.0   30.0        Lightweight Division
# 1       205.0   27.0        Heavyweight Division
# 2       135.0   31.0       Bantamweight Division
# 3       155.0   32.0        Lightweight Division
# 4       205.0   34.0  Light Heavyweight Division
# 5       170.0   38.0       Welterweight Division
# 6       155.0   26.0        Lightweight Division
# 7       170.0   35.0       Middleweight Division
# 8       205.0   29.0  Light Heavyweight Division
# 9       155.0   33.0        Lightweight Division
#
#                                                label  lab_num
# 0  Distance Striking Heavy - Non dominant wrestli...        6
# 1  Distance Striking Heavy - Non dominant wrestli...        6
# 2  Wrestling/Grappling Heavy - Non dominant wrest...        9
# 3  Distance Striking Heavy - Dominant grappling/w...        5
# 4        Balanced - Non dominant wrestling/grappling        2
# 5            Balanced - Dominant wrestling/grappling        1
# 6  Wrestling/Grappling Heavy - Dominant wrestling...        8
# 7        Balanced - Non dominant wrestling/grappling        2
# 8  Wrestling/Grappling Heavy - Dominant wrestling...        8
# 9                                   Balanced fighter        3
#
# [10 rows x 65 columns]

# %%
ufc_df.isnull().sum()
# Out:
# Fighter         0
# KD              0
# SUB_ATT         0
# SIG_STR_pct     0
# REV             0
#                ..
# Weight_lbs     10
# R_age          27
# division        0
# label           0
# lab_num         0
# Length: 65, dtype: int64

# %%
division_df = ufc_df.groupby('division')
division_mean = round(division_df.mean(), 2)

# iterate over each row in the dataframe
for index, row in ufc_df.iterrows():
    # get the fighter's division and the values for CTRL_RT, Height, Weight, and Reach
    division = row['division']
    ctrl_rt = row['CTRL_RT']
    height = row['Height_cms']
    weight = row['Weight_lbs']
    reach = row['Reach_cms']
    age = row['R_age']
    
    # check if any of the values are missing
    if pd.isna(ctrl_rt) or pd.isna(height) or pd.isna(weight) or pd.isna(reach):
        # if any of the values are missing, impute with the division mean for that column
        if pd.isna(ctrl_rt):
            ufc_df.at[index, 'CTRL_RT'] = division_mean.loc[division, 'CTRL_RT']
        if pd.isna(height):
            ufc_df.at[index, 'Height_cms'] = division_mean.loc[division, 'Height_cms']
        if pd.isna(weight):
            ufc_df.at[index, 'Weight_lbs'] = division_mean.loc[division, 'Weight_lbs']
        if pd.isna(reach):
            ufc_df.at[index, 'Reach_cms'] = division_mean.loc[division, 'Reach_cms']
        if pd.isna(age):
            ufc_df.at[index, 'R_age'] = division_mean.loc[division, 'R_age']
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_19620\466790076.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   division_mean = round(division_df.mean(), 2)

# %%
# create a bar plot
division_mean.plot(kind='bar', figsize=(15, 8))

# set plot title and axis labels
plt.title('UFC Fighter Stats by Division')
plt.xlabel('Division')
plt.ylabel('Mean Value')

# show legend
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# show plot
plt.show()

# %%
# Create a 5 by 6 matrix of subplots
fig, axes = plt.subplots(nrows=5, ncols=13, figsize=(40, 25))
axes = axes.ravel()

# Create histograms for each numerical column
for i, col in enumerate(ufc_df.select_dtypes(include=['float64', 'int64']).columns):
    division_df[col].hist(alpha=0.5, ax=axes[i])
    axes[i].set_title(col)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')
    if i == 0:
        axes[i].legend(division_df.groups.keys())

# Remove any unused subplots
for i in range(len(ufc_df.select_dtypes(include=['float64', 'int64']).columns), len(axes)):
    fig.delaxes(axes[i])

# Adjust the spacing between subplots
fig.tight_layout()

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import PowerTransformer, StandardScaler

# %%
ufc_df.columns
# Out:
# Index(['Fighter', 'KD', 'SUB_ATT', 'SIG_STR_pct', 'REV', 'SIG_STR._lan',
#        'SIG_STR._att', 'TOTAL_STR._lan', 'TOTAL_STR._att', 'TD_lan', 'TD_att',
#        'HEAD_lan', 'HEAD_att', 'BODY_lan', 'BODY_att', 'LEG_lan', 'LEG_att',
#        'DISTANCE_lan', 'DISTANCE_att', 'CLINCH_lan', 'CLINCH_att',
#        'GROUND_lan', 'GROUND_att', 'pct_SIG_STR', 'pct_TOTAL_STR', 'pct_TD',
#        'pct_HEAD', 'pct_BODY', 'pct_LEG', 'pct_DISTANCE', 'pct_CLINCH',
#        'pct_GROUND', 'DIST_pct', 'CTRL_RT', 'SLpM', 'Str_Acc', 'SApM',
#        'Str_Def', 'TD_Avg', 'TD_Acc', 'TD_Def', 'Sub_Avg', 'CTRL', 'CTRLLD',
#        'fight_time', 'avg_fight_time', 'DIST', 'Total_Fights', 'Win', 'Loss',
#        'Draw', 'longest_win_streak', 'win_by_Decision_Majority',
#        'win_by_Decision_Split', 'win_by_Decision_Unanimous', 'win_by_KO/TKO',
#        'win_by_Submission', 'win_by_TKO_Doctor_Stoppage', 'Height_cms',
#        'Reach_cms', 'Weight_lbs', 'R_age', 'division', 'label', 'lab_num'],
#       dtype='object')

# %%
num_ufc = ufc_df[['KD', 'SIG_STR_pct','SLpM', 'Str_Acc', 'SApM', 
          'Str_Def', 'DIST_pct','pct_HEAD', 'pct_BODY', 'pct_LEG',
          'pct_TD', 'TD_Avg', 'TD_Acc', 'CTRL_RT','TD_Def', 'Sub_Avg', 'SUB_ATT', 'REV',    
          'Height_cms', 'Weight_lbs','Reach_cms', 'R_age', 
          'Win', 'Loss', 'Draw', 'Total_Fights', 'fight_time', 'avg_fight_time',
          'longest_win_streak', 'win_by_Decision_Majority', 'win_by_Decision_Split',
          'win_by_Decision_Unanimous', 'win_by_KO/TKO', 'win_by_Submission',
          'win_by_TKO_Doctor_Stoppage']]
num_ufc = num_ufc.dropna()

print(len(num_ufc.columns))
# Out:
# 35

# %%
# assume num_ufc is a NumPy array or Pandas DataFrame with multiple columns
cols_to_exclude = ['KD', 'SUB_ATT', 'REV', 'Draw']  # list of column names to exclude
included_cols = [col for col in num_ufc.columns if col not in cols_to_exclude]  # select columns to include

# %%
# Create a StandardScaler object
scaler = StandardScaler()

# Fit and transform the data using the StandardScaler
num_ufc_scaled = scaler.fit_transform(num_ufc)

# Create a PowerTransformer object
power_transformer = PowerTransformer()

# Fit and transform the scaled data using the PowerTransformer
num_ufc_trsf = power_transformer.fit_transform(num_ufc_scaled)

pca_ufc = pd.DataFrame(num_ufc_trsf, columns=num_ufc.columns)

# %%
# Create a 5 by 6 matrix of subplots
fig, axes = plt.subplots(nrows=5, ncols=7, figsize=(40, 25))
axes = axes.ravel()

# Create histograms for each numerical column
for i, col in enumerate(pca_ufc.columns):
    pca_ufc[col].hist(alpha=0.5, ax=axes[i])
    axes[i].set_title(col)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')
    if i == 0:
        axes[i].legend(pca_ufc.keys())

# Remove any unused subplots
for i in range(len(ufc_df.select_dtypes(include=['float64', 'int64']).columns), len(axes)):
    fig.delaxes(axes[i])

# Adjust the spacing between subplots
# fig.tight_layout()

# %%
pca_ufc.isnull().sum()
# Out:
# KD                            0
# SIG_STR_pct                   0
# SLpM                          0
# Str_Acc                       0
# SApM                          0
# Str_Def                       0
# DIST_pct                      0
# pct_HEAD                      0
# pct_BODY                      0
# pct_LEG                       0
# pct_TD                        0
# TD_Avg                        0
# TD_Acc                        0
# CTRL_RT                       0
# TD_Def                        0
# Sub_Avg                       0
# SUB_ATT                       0
# REV                           0
# Height_cms                    0
# Weight_lbs                    0
# Reach_cms                     0
# R_age                         0
# Win                           0
# Loss                          0
# Draw                          0
# Total_Fights                  0
# fight_time                    0
# avg_fight_time                0
# longest_win_streak            0
# win_by_Decision_Majority      0
# win_by_Decision_Split         0
# win_by_Decision_Unanimous     0
# win_by_KO/TKO                 0
# win_by_Submission             0
# win_by_TKO_Doctor_Stoppage    0
# dtype: int64

# %%
pca_ufc.columns
# Out:
# Index(['KD', 'SIG_STR_pct', 'SLpM', 'Str_Acc', 'SApM', 'Str_Def', 'DIST_pct',
#        'pct_HEAD', 'pct_BODY', 'pct_LEG', 'pct_TD', 'TD_Avg', 'TD_Acc',
#        'CTRL_RT', 'TD_Def', 'Sub_Avg', 'SUB_ATT', 'REV', 'Height_cms',
#        'Weight_lbs', 'Reach_cms', 'R_age', 'Win', 'Loss', 'Draw',
#        'Total_Fights', 'fight_time', 'avg_fight_time', 'longest_win_streak',
#        'win_by_Decision_Majority', 'win_by_Decision_Split',
#        'win_by_Decision_Unanimous', 'win_by_KO/TKO', 'win_by_Submission',
#        'win_by_TKO_Doctor_Stoppage'],
#       dtype='object')

# %%
pca = PCA()
pca.fit(pca_ufc)
# Out:
# PCA()

# %%
plt.plot(pca.explained_variance_, 'b')
plt.plot(pca.explained_variance_, 'bo')

# %%
first_component_loadings = list(pca.components_[0])
second_component_loadings = list(pca.components_[1])
third_component_loadings = list(pca.components_[2])

loading_scores = {'Component 1': first_component_loadings,
                 'Component 2': second_component_loadings,
                 'Component 3': third_component_loadings}

df_loading_scores = pd.DataFrame(loading_scores)
df_loading_scores.index = list(pca_ufc.columns)

df_loading_scores
# Out:
#                             Component 1  Component 2  Component 3
# KD                             0.235762    -0.063457     0.151649
# SIG_STR_pct                    0.322153    -0.015434     0.051656
# SLpM                           0.099689    -0.101318    -0.083406
# Str_Acc                        0.074401     0.251428    -0.132131
# SApM                          -0.036162    -0.215393     0.003866
# Str_Def                        0.102025    -0.108769    -0.160432
# DIST_pct                       0.013601    -0.313643     0.148524
# pct_HEAD                       0.098403     0.260922    -0.059322
# pct_BODY                       0.031351     0.246138     0.012176
# pct_LEG                       -0.001125     0.137144    -0.034520
# pct_TD                         0.098561     0.252605    -0.227436
# TD_Avg                         0.085291     0.267784    -0.327730
# TD_Acc                         0.108583     0.236284    -0.274332
# CTRL_RT                        0.077822     0.141708    -0.199367
# TD_Def                         0.100720    -0.068775    -0.052060
# Sub_Avg                        0.097826     0.212482    -0.140720
# SUB_ATT                        0.217969     0.106663    -0.075338
# REV                            0.149959     0.024839    -0.062843
# Height_cms                     0.020201     0.294884     0.412337
# Weight_lbs                     0.008874     0.296079     0.425728
# Reach_cms                      0.018281     0.286711     0.408672
# R_age                          0.167900    -0.023683     0.090620
# Win                            0.283298    -0.014191     0.095817
# Loss                           0.242478    -0.141919    -0.012943
# Draw                           0.075371    -0.029360     0.038890
# Total_Fights                   0.321493    -0.069425     0.065545
# fight_time                     0.307104    -0.126748     0.008354
# avg_fight_time                 0.146563    -0.033522     0.040984
# longest_win_streak             0.301092    -0.031297     0.024529
# win_by_Decision_Majority       0.051852     0.051335     0.036940
# win_by_Decision_Split          0.160127    -0.156187    -0.006203
# win_by_Decision_Unanimous      0.256335    -0.092095    -0.064386
# win_by_KO/TKO                  0.237696    -0.014741     0.189028
# win_by_Submission              0.189033     0.087024    -0.040674
# win_by_TKO_Doctor_Stoppage     0.090664    -0.002271     0.063535

# %%
pca.components_[1]
# Out:
# array([-0.06345723, -0.01543407, -0.10131829,  0.25142766, -0.21539339,
#        -0.10876918, -0.31364332,  0.26092219,  0.24613776,  0.13714433,
#         0.25260459,  0.26778383,  0.23628359,  0.14170757, -0.06877503,
#         0.21248202,  0.10666255,  0.02483935,  0.29488413,  0.2960794 ,
#         0.2867109 , -0.02368295, -0.01419079, -0.14191874, -0.02935998,
#        -0.06942549, -0.1267478 , -0.03352173, -0.03129666,  0.0513347 ,
#        -0.15618746, -0.09209503, -0.01474115,  0.08702422, -0.00227107])

# %%
component_scores = pca_ufc.dot(pca.components_.T[0])
component_scores1 = pca_ufc.dot(pca.components_.T[1])
component_scores2 = pca_ufc.dot(pca.components_.T[2])
component_scores3 = pca_ufc.dot(pca.components_.T[3])
component_scores_df = pd.DataFrame({'Component Score 1': component_scores,
                                   'Component Score 2': component_scores1,
                                   'Component Score 3': component_scores2,
                                   'Component Score 4': component_scores3,})
combined_df = pd.concat([num_ufc, component_scores_df], axis=1)

# %%
fig, ax = plt.subplots(figsize=(8, 12))  # set the figure size to 8x6 inches

ax.barh(pca_ufc.columns, pca.components_[0])
ax.set_xlabel('PCA Component 1')
ax.set_ylabel('Features')
ax.set_title('PCA Feature Importance')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 12))  # set the figure size to 8x6 inches

ax.barh(pca_ufc.columns, pca.components_[1])
ax.set_xlabel('PCA Component 2')
ax.set_ylabel('Features')
ax.set_title('PCA Feature Importance')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 12))  # set the figure size to 8x6 inches

ax.barh(pca_ufc.columns, pca.components_[2])
ax.set_xlabel('PCA Component 3')
ax.set_ylabel('Features')
ax.set_title('PCA Feature Importance')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 12))  # set the figure size to 8x6 inches

ax.barh(pca_ufc.columns, pca.components_[4])
ax.set_xlabel('PCA Component 4')
ax.set_ylabel('Features')
ax.set_title('PCA Feature Importance')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 12))  # set the figure size to 8x6 inches

ax.barh(pca_ufc.columns, pca.components_[5])
ax.set_xlabel('PCA Component 5')
ax.set_ylabel('Features')
ax.set_title('PCA Feature Importance')
plt.show()

# %%
loading_scores_1 = pca.components_[0]
loading_scores_2 = pca.components_[1]
loading_scores_3 = pca.components_[2]

print(loading_scores_1)
print(loading_scores_2)
print(loading_scores_3)
# Out:
# [ 0.23576198  0.32215279  0.09968879  0.07440085 -0.03616178  0.10202529
#   0.01360135  0.09840261  0.03135142 -0.00112485  0.0985606   0.08529076
#   0.1085833   0.0778219   0.10071997  0.09782635  0.21796925  0.14995892
#   0.02020131  0.00887404  0.01828149  0.16790033  0.28329849  0.24247835
#   0.07537063  0.32149312  0.30710426  0.14656329  0.3010918   0.05185202
#   0.16012688  0.25633451  0.23769581  0.18903301  0.09066399]
# [-0.06345723 -0.01543407 -0.10131829  0.25142766 -0.21539339 -0.10876918
#  -0.31364332  0.26092219  0.24613776  0.13714433  0.25260459  0.26778383
#   0.23628359  0.14170757 -0.06877503  0.21248202  0.10666255  0.02483935
#   0.29488413  0.2960794   0.2867109  -0.02368295 -0.01419079 -0.14191874
#  -0.02935998 -0.06942549 -0.1267478  -0.03352173 -0.03129666  0.0513347
#  -0.15618746 -0.09209503 -0.01474115  0.08702422 -0.00227107]
# [ 0.1516491   0.05165638 -0.08340599 -0.13213116  0.00386647 -0.16043207
#   0.14852403 -0.059322    0.01217568 -0.03452029 -0.22743629 -0.32772972
#  -0.27433184 -0.1993672  -0.05205977 -0.14072037 -0.07533803 -0.06284319
#   0.41233677  0.42572788  0.40867249  0.09062     0.0958172  -0.01294274
#   0.03889007  0.06554517  0.00835378  0.04098393  0.02452932  0.03694011
#  -0.00620346 -0.06438645  0.18902752 -0.04067357  0.06353525]

# %%
p4p_fighters = ['Alexander Volkanovski', 'Anderson Silva', 'Brandon Moreno', 'Charles Oliveira',
               'Conor McGregor', 'Demetrious Johnson', 'Dustin Poirier', 'Francis Ngannou',
               'Georges St-Pierre', 'Henry Cejudo', 'Israel Adesanya', 'Jon Jones', 'Jose Aldo',
               'Justin Gaethje', 'Kamaru Usman', 'Khabib Nurmagomedov', 'Stipe Miocic']

# Create a new dataframe with observations only for the listed fighters
new_df = ufc_df[ufc_df['Fighter'].isin(p4p_fighters)]

# Display the new dataframe
new_df.head()
# Out:
#                    Fighter  KD  SUB_ATT  SIG_STR_pct  REV  SIG_STR._lan  \
# 72   Alexander Volkanovski   4        3         5.12    1           821
# 105         Anderson Silva  18        6        15.77    1           832
# 240         Brandon Moreno   2        6         4.14    3           482
# 321       Charles Oliveira   4       35        13.70    5           605
# 406         Conor McGregor  13        0         6.63    1           572
#
#      SIG_STR._att  TOTAL_STR._lan  TOTAL_STR._att  TD_lan  ...  win_by_KO/TKO  \
# 72           1468             914            1576      19  ...              3
# 105          1410            1029            1632       3  ...             11
# 240          1243             700            1482      19  ...              1
# 321          1156             904            1479      33  ...              2
# 406          1166             754            1359       5  ...              8
#
#      win_by_Submission  win_by_TKO_Doctor_Stoppage  Height_cms  Reach_cms  \
# 72                   0                           0      167.64     180.34
# 105                  3                           0      187.96     195.58
# 240                  2                           0      170.18     177.80
# 321                 14                           0      177.80     187.96
# 406                  0                           0      175.26     187.96
#
#      Weight_lbs  R_age                    division  \
# 72        145.0   37.0  Light Heavyweight Division
# 105       185.0   41.0       Middleweight Division
# 240       125.0   34.0          Flyweight Division
# 321       155.0   35.0      Featherweight Division
# 406       155.0   38.0        Lightweight Division
#
#                                                  label  lab_num
# 72   Distance Striking Heavy - Dominant grappling/w...        5
# 105  Distance Striking Heavy - Non dominant wrestli...        6
# 240            Balanced - Dominant wrestling/grappling        1
# 321               Wrestling/Grappling Heavy - Balanced        7
# 406                                   Balanced fighter        3
#
# [5 rows x 65 columns]

# %%
p4p_df = new_df[['Fighter', 'KD', 'SIG_STR_pct','SLpM', 'Str_Acc', 'SApM', 
          'Str_Def', 'DIST_pct','pct_HEAD', 'pct_BODY', 'pct_LEG',
          'pct_TD', 'TD_Avg', 'TD_Acc', 'CTRL_RT','TD_Def', 'Sub_Avg', 'SUB_ATT', 'REV',    
          'Height_cms', 'Weight_lbs','Reach_cms', 'R_age', 
          'Win', 'Loss', 'Draw', 'Total_Fights', 'fight_time', 'avg_fight_time',
          'longest_win_streak', 'win_by_Decision_Majority', 'win_by_Decision_Split',
          'win_by_Decision_Unanimous', 'win_by_KO/TKO', 'win_by_Submission',
          'win_by_TKO_Doctor_Stoppage']]

# %%
# Calculate total fights by fighter
total_fights = p4p_df['Total_Fights'].values
fighters = p4p_df['Fighter'].values
fighters2 = ufc_df['Fighter'].values

# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(fighters, total_fights)
plt.xticks(rotation=90)
plt.xlabel('Fighter')
plt.ylabel('Total Fights')
plt.title('Total Fights by Fighter')
plt.show()

# %%
# Extract the relevant columns
sig_str_pct = p4p_df['SIG_STR_pct'].values
slpm = p4p_df['SLpM'].values

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(slpm, sig_str_pct)
plt.xlabel('Significant Strikes Landed per Minute (SLpM)')
plt.ylabel('Significant Strike Accuracy (%)')
plt.title('Significant Strike Accuracy vs. SLpM')
plt.show()

# %%
# Extract the relevant columns
win_by_ko_tko = p4p_df['win_by_KO/TKO'].sum()
win_by_submission = p4p_df['win_by_Submission'].sum()
win_by_decision_unanimous = p4p_df['win_by_Decision_Unanimous'].sum()
win_by_decision_split = p4p_df['win_by_Decision_Split'].sum()
win_by_decision_majority = p4p_df['win_by_Decision_Majority'].sum()

# Create a pie chart
labels = ['KO/TKO', 'Submission', 'Decision (Unanimous)', 'Decision (Split)', 'Decision (Majority)']
sizes = [win_by_ko_tko, win_by_submission, win_by_decision_unanimous, win_by_decision_split, win_by_decision_majority]
plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Win Distribution by Finish Type')
plt.show()

# %%
import seaborn as sns

# Create a box plot
plt.figure(figsize=(30, 20))
sns.boxplot(x='Weight_lbs', y='Reach_cms', data=ufc_df)
plt.xlabel('Weight Class (lbs)')
plt.ylabel('Reach (cm)')
plt.title('Reach Distribution by Weight Class')
plt.xticks(rotation=90)
plt.show()

# %%
# Create a histogram
plt.figure(figsize=(8, 6))
plt.hist(ufc_df['avg_fight_time'], bins=20, edgecolor='black')
plt.xlabel('Fight Time (minutes)')
plt.ylabel('Frequency')
plt.title('Fight Time Distribution')
plt.show()

# %%
# Select the striking and grappling metrics columns
metrics = ['KD', 'SIG_STR_pct', 'SLpM', 'Str_Acc', 'SApM', 'Str_Def', 'DIST_pct',
           'pct_HEAD', 'pct_BODY', 'pct_LEG', 'pct_TD', 'TD_Avg', 'TD_Acc', 'CTRL_RT',
           'TD_Def', 'Sub_Avg', 'SUB_ATT', 'REV']

# Calculate the mean values for each metric
mean_values = p4p_df[metrics].mean()

# Create a bar plot
plt.figure(figsize=(12, 6))
mean_values.plot(kind='bar')
plt.xlabel('Metrics')
plt.ylabel('Mean Value')
plt.title('Comparison of Striking and Grappling Metrics')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Get the fighters' names
fighters = p4p_df['Fighter']

# Get the mean values for each metric per fighter
mean_values = p4p_df[metrics].mean()

# Create an array for the x-axis positions
x = np.arange(len(metrics))

# Create the bar plot
plt.figure(figsize=(12, 6))
plt.bar(x, mean_values, align='center')
plt.xlabel('Metrics')
plt.ylabel('Mean Value')
plt.title('Comparison of Striking and Grappling Metrics by Fighter')
plt.xticks(x, metrics, rotation=45, ha='right')
plt.legend(fighters, loc='best')
plt.tight_layout()
plt.show()
